# %% [markdown]
# ## 3.8.1.4.daum_news_list_final

# %%
import requests
import lxml.html
import pandas as pd
import sqlite3
from pandas.io import sql
import os
import time

# %%
def db_save(NEWS_LIST):
    with sqlite3.connect(os.path.join('.', 'sqliteDB')) as con:
        try:
            NEWS_LIST.to_sql(name = 'NEWS_LIST', con=con, index=False, if_exists='append')
        except Exception as e:
            print(str(e))
        print(len(NEWS_LIST), '건 저장완료')

# %%
def db_delete():
    with sqlite3.connect(os.path.join('.', 'sqliteDB')) as con:
        try:
            cur = con.cursor()
            sql = 'DELETE FROM NEWS_LIST'
            cur.execute(sql)
        except Exception as e:
            print(str(e))

# %%
def db_select():
    with sqlite3.connect(os.path.join('.', 'sqliteDB')) as con:
        try:
            query = 'SELECT * FROM NEWS_LIST'
            NEWS_LIST = pd.read_sql(query, con=con)
        except Exception as e:
            print(str(e))
        return NEWS_LIST

# %%
import re
import string

def get_detail(url):
    body = []
    punc = '[!"#$%&\'()*+,-./:;<=>?[\]^_`{|}~“”·]'
    response = requests.get(url)
    root = lxml.html.fromstring(response.content)
    for p in root.xpath('//*[@id="harmonyContainer"]/section/p'):
        if p.text:
            body.append(re.sub(punc, '', p.text))
    full_body = ' '.join(body)

# %%
page = 58
max_page = 0
REG_DATE = '20200819'

# %%
while(True):
    df_list = []
    response = requests.get('http://news.daum.net/breakingnews/digital?page={}&regDate={}'\
                           .format(page, REG_DATE))
    root = lxml.html.fromstring(response.content)
    for li in root.xpath('//*[@id="mArticle"]/div[3]/ul/li'):
        a = li.xpath('div/strong/a')[0]
        url = a.get('href')
        article = get_detail(url)
        df = pd.DataFrame({'URL': [url], 'TITLE': [a.text], 'ARTICLE': [article]})
        df_list.append(df)
    
    if df_list:
        df_10 = pd.concat(df_list)
        db_save(df_10)
        
    # 페이지 번호 중에서 max 페이지 가져오기
    for a in root.xpath('//*[@id="mArticle"]/div[3]/div/span/a'):
        try:
            num = int(a.text)
            if max_page < num:
                max_page = num
        except:
            pass
        
    # 마지막 페이지 여부 확인
    span = root.xpath('//*[@id="mArticle"]/div[3]/div/span/a[@class="btn_page btn_next"]')
    
    if (len(span) <= 0) & (page > max_page):
        break
    else:
        page = page + 1
    time.sleep(1)
# Out:
# 15 건 저장완료
# 15 건 저장완료
# 15 건 저장완료
# 13 건 저장완료

# %%
#db_delete()

# %%
print(db_select())
# Out:
#                                        URL  \
# 0   https://v.daum.net/v/20200819084702255
# 1   https://v.daum.net/v/20200819084617234
# 2   https://v.daum.net/v/20200819084529215
# 3   https://v.daum.net/v/20200819084517208
# 4   https://v.daum.net/v/20200819084251134
# 5   https://v.daum.net/v/20200819083702982
# 6   https://v.daum.net/v/20200819083528956
# 7   https://v.daum.net/v/20200819083303903
# 8   https://v.daum.net/v/20200819083135880
# 9   https://v.daum.net/v/20200819082825812
# 10  https://v.daum.net/v/20200819082814806
# 11  https://v.daum.net/v/20200819082703784
# 12  https://v.daum.net/v/20200819082610764
# 13  https://v.daum.net/v/20200819082557759
# 14  https://v.daum.net/v/20200819082503742
# 15  https://v.daum.net/v/20200819082501741
# 16  https://v.daum.net/v/20200819082324702
# 17  https://v.daum.net/v/20200819081608550
# 18  https://v.daum.net/v/20200819080415266
# 20                        中 HKC OLED 투자 보류..코로나19에 발목    None
# 21               '리모컨으로 채널돌리기 그만'..LG헬로, 넷플릭스처럼 UI 개편    None
# 22          '최불암 시리즈'가 광고로?..게임광고에 분 '뉴트로' 바람 [Oh!덕후]    None
# 23              트렌드마이크로, IT환경 보안위협 탐지·대응 'XDR 플랫폼' 출시    None
# 24                 6가지 색 '갤럭시S20 팬에디션' 이미지 유출..10월 출시    None
# 25                      오리온, '초코파이情 바나나' 4년 만에 리뉴얼 출시    None
# 26                            이웃집 확진자에 '도로 재택' 들어간 판교    None
# 27               "토종 OTT '역차별' 없도록"..OTT정책협의체 내주 실무회의    None
# 28                         태양계 밖 외계에서 온 '오우무아무아' 정체는?    None
# 29              "술 취해 휘청거리는 당신, 스마트폰은 안다"..개인 음주경고 성큼    None
# 30                    SKT, 코로나19로 채용난 겪는 협력사 50개사 돕는다    None
# 31        [사이테크 플러스] 음주사고로 절친잃은 슬픔에..스마트폰으로 걸음분석 과음파악    None
# 32             퍼스널 트레이닝을 비대면으로? - 스포투 [혁신, 스타트업을 만나다]    None
# 33                         쉽게 못 풀걸?..삼성, 그림으로 휴대폰 잠근다    None
# 34         [과학게시판] 정병선 과기차관, 연구장비산업 경쟁력 강화방안 간담회 가져 外    None
# 35       '전광훈 코로나 확진' 일파만파에 설훈 "통합당이 집회 독려..대국민 사과해야"    None
# 36                          "내가 샀다"는 삼성 모니터 리뷰도 '뒷광고'    None
# 37          네이버웹툰, 북미 1위 '로어 올림푸스' 한국어 버전 19일 국내 첫 공개    None
# 38              韓 제약사, 코로나19 악재에도 다양한 채널 통한 R&D 투자 확대    None
# 39                    기로에 선 화웨이 스마트폰 사업.. 11월에 운명 갈린다    None
# 40               페이스북 vs 방통위 '망 품질 책임론' 2심 결과 이번주 나온다    None
# 41              움츠리는 메모리 시장.. 하반기 삼성⋅하이닉스 실적 우려 현실화되나    None
# 42                        "통행세 더 내라" 구글·애플 횡포에 앱시장 전운    None
# 43                      고개드는 토종 OTT 통합론..넷플릭스 대항마 나올까    None
# 44                  카카오페이지, 글로벌 역량 갖춘 제작사 '크로스픽쳐스' 인수    None
# 45                 "이태원때처럼"..기지국 정보로 광화문집회 참석자 알 수 있나    None
# 46                     계속되는 코로나19 돌연변이..'칵테일 항체'로 잡는다    None
# 47                              투명한 공원 공중화장실, 왜 만들었을까    None
# 48                            부산 특구는 암호화폐를 비켜가지 않습니데이    None
# 49                   DAXPO 2020, 코로나19 이후 새로운 금융 토론한다    None
# 50                   코로나19 재확산 위험 커졌다.. 여름잠 준비하는 IT업계    None
# 51                               LG 벨벳, 최적의 메모리 용량 제안    None
# 52                      5G 보급과 함께 쑥쑥.. VR게임 대중화시대 열린다    None
# 53                "게임에 빠진 아이와 소통하려면..'게임의 룰'부터 파악하세요"    None
# 54  "재택근무부터 온라인 콘서트까지..코로나19로 모바일이 삶에 뿌리내렸다"[신무경의 ...    None
# 55               보름 앞으로 다가온 반쪽 행사 'IFA 2020'..강행 배경은?    None
# 56                    방심위, 진공 청소기 흡입력 오인케한 공영쇼핑에 '주의'    None
# 57            [TF초점] 기대 높아진 갤노트20, 상반기 갤S20 부진까지 씻어낼까    None
